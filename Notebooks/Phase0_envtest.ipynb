# %% [markdown]
# # Phase 0 of the Chopin Waltz Completion (CWC) project.
#
# ## Author: Jawad Mallat
#
# ### Description: This is for testing the environment and tools that we are going to use during the project

# %%
import torch
import music21
import pretty_midi
import miditok
import matplotlib

print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"music21 version: {music21.VERSION_STR}")
print(f"MidiTok imported successfully")
print("All imports successful!")
# Out:
# PyTorch version: 2.10.0
# CUDA available: False
# music21 version: 9.9.1
# MidiTok imported successfully
# All imports successful!
